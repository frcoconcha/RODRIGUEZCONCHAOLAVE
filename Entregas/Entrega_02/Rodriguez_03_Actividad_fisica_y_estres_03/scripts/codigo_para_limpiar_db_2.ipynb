# %%
import pandas as pd
df_tabla1=pd.read_excel("/content/drive/MyDrive/database_raw_01.xlsx")

# %% [markdown]
# Tabla 1: Niveles de actividad física y estrés

# %%
df_tabla1
# Out:
#                                                   .1  FRECUENCIA  PORCENTAJE  \
# 0   Nivel de actividad física                   bajo         8.0        11.3
# 1                                           moderado        23.0        32.4
# 2                                               alto        40.0        56.3
# 3           Nivel de ansiedad                 normal         NaN         NaN
# 4                                               leve         NaN         NaN
# 5                                           moderado         NaN         NaN
# 6                                             severo         NaN         NaN
# 7                              extremadamente severo         NaN         NaN
# 8             Nivel de estrés                 normal        29.0        40.8
# 9                                               leve        12.0        16.9
# 10                                          moderado        16.0        22.5
# ...

# %%
df_tabla1.isnull()
# Out:
#               .1  FRECUENCIA  PORCENTAJE  PORCENTAJE VÁLIDO  \
# 0   False  False       False       False              False
# 1   False  False       False       False              False
# 2   False  False       False       False              False
# 3   False  False        True        True               True
# 4   False  False        True        True               True
# 5   False  False        True        True               True
# 6   False  False        True        True               True
# 7   False  False        True        True               True
# 8   False  False       False       False              False
# 9   False  False       False       False              False
# 10  False  False       False       False              False
# 11  False  False       False       False              False
# 12  False  False       False       False              False
#
#     PORCENTAJE ACUMULADO
# 0                  False
# 1                  False
# 2                  False
# ...

# %%
df_tabla1.dropna()
# Out:
#                                                   .1  FRECUENCIA  PORCENTAJE  \
# 0   Nivel de actividad física                   bajo         8.0        11.3
# 1                                           moderado        23.0        32.4
# 2                                               alto        40.0        56.3
# 8             Nivel de estrés                 normal        29.0        40.8
# 9                                               leve        12.0        16.9
# 10                                          moderado        16.0        22.5
# 11                                            severo         8.0        11.3
# 12                             extremadamente severo         6.0         8.5
#
#     PORCENTAJE VÁLIDO  PORCENTAJE ACUMULADO
# 0                11.3                  11.3
# 1                32.4                  43.7
# 2                56.3                 100.0
# 8                40.8                  40.8
# 9                16.9                  57.7
# ...

# %% [markdown]
# Tabla 2: Relación entre nivel de actividad física y estrés

# %%
df_tabla2=pd.read_excel("/content/drive/MyDrive/database_raw_02.xlsx")
df_tabla2
# Out:
#   Relación entre nivel de actividad física y estrés  \
# 0                         Nivel de actividad física
# 1
# 2                                 Nivel de ansiedad
# 3
# 4                                   Nivel de estrés
# 5
#
#                               Nivel de actividad física Nivel de ansiedad  \
# 0  Coeficiente de correlación                         1            -,251*
# 1            Sig. (bilateral)                                       0.035
# 2  Coeficiente de correlación                       NaN                 1
# 3            Sig. (bilateral)                       NaN
# 4  Coeficiente de correlación                  -0,366**           0,763**
# 5            Sig. (bilateral)                     0.002                 0
#
#   Nivel de estrés
# 0         -,366**
# 1           0.002
# 2             NaN
# 3               0
# 4               1
# 5

# %% [markdown]
# Tabla 3: Tabla cruzada entre nivel de actividad física y estrés

# %%
df_tabla3=pd.read_excel("/content/drive/MyDrive/database_raw_03.xlsx")
df_tabla3
# Out:
#                     Niveles de estrés  \
# 0
# 1      Nivel de actividad física bajo
# 2
# 3  Nivel de actividad física moderado
# 4
# 5      Nivel de actividad física alto
# 6
# 7
#
#                                                 Normal  Leve  Moderado  \
# 0                                                  1.0   2.0       1.0
# 1  Recuento % dentro de nivel actividad física    12.5  25.0      12.5
# 2                                                  7.0   2.0       8.0
# 3  Recuento % dentro de nivel actividad física    30.4   8.8      34.8
# 4                                                 21.0   8.0       7.0
# 5  Recuento % dentro de nivel actividad física    52.5  20.0      17.5
# 6                                                 29.0  12.0      16.0
# 7  Recuento % dentro de nivel actividad física    40.8  16.9      22.5
#
#    Severo  Extremadamente severo  Total
# 0     4.0                    0.0      8
# 1    50.0                    0.0    100
# ...

# %%
df_tabla3.isnull()
# Out:
#    Niveles de estrés         Normal   Leve  Moderado  Severo  \
# 0              False  False   False  False     False   False
# 1              False  False   False  False     False   False
# 2              False  False   False  False     False   False
# 3              False  False   False  False     False   False
# 4              False  False   False  False     False   False
# 5              False  False   False  False     False   False
# 6              False  False   False  False     False   False
# 7              False  False   False  False     False   False
#
#    Extremadamente severo  Total
# 0                  False  False
# 1                  False  False
# 2                  False  False
# 3                  False  False
# 4                  False  False
# 5                  False  False
# 6                  False  False
# 7                  False  False

# %%
df_tabla3.dropna()
# Out:
#                     Niveles de estrés  \
# 0
# 1      Nivel de actividad física bajo
# 2
# 3  Nivel de actividad física moderado
# 4
# 5      Nivel de actividad física alto
# 6
# 7
#
#                                                 Normal  Leve  Moderado  \
# 0                                                  1.0   2.0       1.0
# 1  Recuento % dentro de nivel actividad física    12.5  25.0      12.5
# 2                                                  7.0   2.0       8.0
# 3  Recuento % dentro de nivel actividad física    30.4   8.8      34.8
# 4                                                 21.0   8.0       7.0
# 5  Recuento % dentro de nivel actividad física    52.5  20.0      17.5
# 6                                                 29.0  12.0      16.0
# 7  Recuento % dentro de nivel actividad física    40.8  16.9      22.5
#
#    Severo  Extremadamente severo  Total
# 0     4.0                    0.0      8
# 1    50.0                    0.0    100
# ...

# %%
df_tabla1.to_csv("database_raw_01.csv", index=False)
df_tabla2.to_csv("database_raw_02.csv", index=False)
df_tabla3.to_csv("database_raw_03.csv", index=False)

# %%
from google.colab import files
files.download("database_raw_01.csv")

# %%
from google.colab import files
files.download("database_raw_02.csv")

# %%
from google.colab import files
files.download("database_raw_03.csv")
